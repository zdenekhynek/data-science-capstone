# %%
import pandas as pd

# %%
params = {
    'tokens-file' : 'data/results/2017-06-26-00-28-20-745635-tokens.csv',
    'tokens-idf-file' : 'data/results/2017-06-26-00-34-41-822267-tokens-idf.csv',
    'clusters-tokens-file' : 'data/results/2017-06-26-00-34-58-852025-clusters-tokens.csv',
    'clusterisation-results-file' : 'data/results/2017-06-26-00-36-48-983930-clusterisation-results.csv',
    'article-clusters-file' : 'data/results/2017-06-26-00-36-56-588418-article-clusters.csv',
    'benchmarks-file' : 'data/results/2017-06-26-00-36-56-703199-benchmarks.csv',
    'num_clusters': 10,
    'cluster_names': [
        '2000s', 'Israel/Palestine', '2000s', 'Isis', 'Muslim Brotherhood (1)',
        'War On Terror/Iraq', 'Bataclan Theatre (1)', 'Middle East', 'Abu Hamza (3)', 
        'Northern Ireland'
    ]
}

# %%
cluster_tokens_df = pd.read_csv(params['clusters-tokens-file'])
cluster_tokens_df.head(100)
# Out:
#     Unnamed: 0                                          0  \
# 0            0                                         'a
# 1            1                            photograph arnd
# 2            2                           photograph arriv
# 3            3                          photograph articl
# 4            4                           photograph artur
# 5            5                          photograph ashraf
# 6            6                            photograph asif
# 7            7                             photograph ask
# 8            8                           photograph asmaa
# 9            9                          photograph associ
# 10          10                         photograph astrapi
# 11          11                             photograph arm
# 12          12                            photograph atta
# 13          13                          photograph attend
# 14          14                        photograph aurelien
# ...

# %%
articles_clusters_df = pd.read_csv(params['article-clusters-file'])
articles_clusters_df[articles_clusters_df['cluster'] == 6].head(100)
# Out:
#       Unnamed: 0                                                 id  cluster  \
# 1525        1525  world/2015/nov/15/paris-attacks-severed-finger...        6
#
#              x         y
# 1525  0.141061 -0.047119

# %%
articles_clusters_df[articles_clusters_df['cluster'] == 9].head(100)
# Out:
#       Unnamed: 0                                                 id  cluster  \
# 9              9  uk-news/2017/feb/03/royal-marine-pleads-guilty...        9
# 27            27  uk-news/2016/aug/24/member-british-forces-arre...        9
# 206          206  uk-news/2016/aug/25/royal-marine-held-on-terro...        9
# 228          228  uk-news/2016/may/17/antrim-weapons-cache-is-mo...        9
# 274          274  uk-news/2016/aug/31/police-given-seven-more-da...        9
# 354          354  uk-news/2016/sep/06/explosive-firearms-found-1...        9
# 362          362  uk-news/2016/jun/08/northern-ireland-police-fe...        9
# 377          377  uk-news/2016/sep/02/royal-marine-ciaran-maxwel...        9
# 413          413  uk-news/2015/sep/18/belfast-psni-arms-cache-se...        9
# 469          469  uk-news/2016/dec/20/man-barry-petticrew-ran-bo...        9
# 661          661  uk-news/2016/aug/07/irish-republican-dissent-m...        9
# ...

# %%
articles_clusters_df[articles_clusters_df['cluster'] == 8].head(100)
# Out:
#       Unnamed: 0                                                 id  cluster  \
# 3562        3562  world/2012/oct/05/abu-hamza-loses-extradition-...        8
# 3944        3944  world/2012/oct/06/abu-hamza-us-court-extradition1        8
# 4914        4914   world/2012/oct/06/abu-hamza-us-court-extradition        8
#
#              x         y
# 3562  0.191078 -0.053896
# 3944  0.182465 -0.051281
# 4914  0.220122 -0.056104

# %%
articles_clusters_df[articles_clusters_df['cluster'] == 1].head(100)
# Out:
#       Unnamed: 0                                                 id  cluster  \
# 263          263  world/2017/jan/08/truck-rammed-into-pedestrian...        1
# 391          391  world/2017/apr/29/fadwa-barghouti-interview-pr...        1
# 499          499  world/2016/aug/04/israel-world-visions-gaza-di...        1
# 508          508  world/2017/may/01/hamas-new-charter-palestine-...        1
# 747          747  world/2016/oct/09/drive-by-shooting-at-jerusal...        1
# 760          760  world/2017/jan/09/israeli-soldiers-killed-in-t...        1
# 792          792  world/2016/sep/19/israeli-police-stabbed-amid-...        1
# 798          798  world/2016/aug/09/israel-second-palestinian-un...        1
# 948          948  world/2016/mar/08/at-least-10-israelis-stabbed...        1
# 978          978  world/2016/may/02/israeli-military-detention-p...        1
# 998          998  world/2016/mar/25/un-envoy-condemns-palestinia...        1
# ...
